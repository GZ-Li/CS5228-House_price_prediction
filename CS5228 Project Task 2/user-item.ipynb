# %% [markdown]
# ## Setting up the Notebook

# %%
import pandas as pd
import numpy as np
from sklearn.metrics import pairwise

# %%
# %load_ext autoreload
# %autoreload 2
from cos_similarity import similarity
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Load the Data
# Load preprocessed data

# %%
df_sample = pd.read_csv('data/clean_data.csv')
df_sample.head()
# Out:
#    property_type  tenure  built_year  num_beds  num_baths  size_sqft  \
# 0              0       0      1988.0       3.0        2.0       1115
# 1              0       0      1992.0       4.0        2.0       1575
# 2              2       2      2022.0       4.0        6.0       3070
# 3              2       2      2023.0       3.0        2.0        958
# 4              2       0      2026.0       2.0        1.0        732
#
#         lat         lng      price
# 0  1.414399  103.837196   514500.0
# 1  1.372597  103.875625   995400.0
# 2  1.298773  103.895798  8485000.0
# 3  1.312364  103.803271  2626000.0
# 4  1.273959  103.843635  1764000.0

# %% [markdown]
# ## Binary Utility Matrix:
# ### Generate input data
# The 50 viewing records are generated in the following way:
# - 45 property records are generated by by using the Pairwise Item Similarity recommender system. Rnadomly choose 45 records out of the top 100 recommendations.
# - 5 property records are selected from the rest of the dataset randomly.

# %%
row_id = 10
k = 100
top_100 = similarity(row_id, df_sample, k)  
# top_100

# %%
np.random.seed(0)
relavent = top_100.sample(n = 45)

# %%
np.random.seed(0)
unrelavent = pd.concat([df_sample, relavent]).drop_duplicates(keep=False).sample(n = 5)

# %%
history_binary = pd.concat([relavent, unrelavent])
history_binary
# Out:
#        property_type  tenure  built_year  num_beds  num_baths  size_sqft  \
# 12357              2       2      2023.0       2.0        1.0        667
# 16535              2       2      2022.0       2.0        1.0        635
# 3772               2       2      2023.0       2.0        1.0        646
# 14186              2       2      2023.0       2.0        1.0        753
# 3904               2       2      2022.0       2.0        1.0        635
# 1126               2       2      2022.0       2.0        1.0        635
# 15909              2       2      2023.0       2.0        1.0        689
# 2770               2       2      2022.0       2.0        1.0        635
# 12448              2       2      2023.0       2.0        1.0        581
# 12863              2       2      2022.0       2.0        1.0        635
# 9522               2       2      2023.0       2.0        1.0        614
# 13801              2       2      2022.0       2.0        1.0        635
# 19481              2       2      2022.0       2.0        1.0        635
# 5938               2       2      2023.0       2.0        1.0        657
# 1401               2       2      2023.0       2.0        1.0        657
# 16955              2       2      2023.0       2.0        1.0        667
# 7953               2       2      2023.0       2.0        1.0        667
# 2234               2       2      2023.0       2.0        1.0        667
# 5961               2       2      2023.0       2.0        1.0        614
# 16249              2       2      2023.0       2.0        1.0        721
# 5537               2       2      2023.0       2.0        1.0        614
# 18985              2       2      2022.0       2.0        1.0        657
# 15360              2       2      2023.0       2.0        1.0        646
# 3692               2       2      2022.0       2.0        1.0        635
# 18973              2       2      2023.0       2.0        1.0        614
# 18594              2       2      2023.0       2.0        1.0        614
# 19534              2       2      2023.0       2.0        1.0        635
# 12238              2       2      2022.0       2.0        1.0        635
# 4653               2       2      2022.0       2.0        1.0        635
# 8430               2       2      2022.0       2.0        1.0        635
# 13255              2       2      2023.0       2.0        1.0        807
# 5636               2       2      2022.0       2.0        1.0        635
# 6312               2       2      2022.0       2.0        1.0        635
# 2504               2       2      2022.0       2.0        1.0        657
# 4886               2       2      2023.0       2.0        1.0        614
# 12682              2       2      2023.0       2.0        1.0        667
#         lat       lng     price
# 0 -0.064416 -0.001504 -0.012176

# %% [markdown]
# ### Get top k recommendations

# %%
k = 3
result_binary = similarity(profile_binary, df_sample, k)
result_binary
# Out:
#       property_type  tenure  built_year  num_beds  num_baths  size_sqft  \
# 7412              2       2      2023.0       2.0        1.0        657
# 8035              2       2      2023.0       2.0        1.0        657
# 1268              2       2      2023.0       2.0        1.0        657
#
#            lat         lng      price
# 7412  1.308766  103.809065  1869000.0
# 8035  1.308766  103.809065  1869000.0
# 1268  1.308766  103.809065  1876600.0

# %% [markdown]
# ### Evaluate the performance by calculating intra-list similrity

# %%
result_binary_intra = pairwise.pairwise_distances(result_binary, metric='cosine')
result_binary_intra.sum()/(k*k - k)
# Out:
# 7.097655796428626e-12

# %% [markdown]
# ## Real-Valued Utility Matrix
# ### Generate input data
# The 50 viewing records are generated in the following way:
# - 25 property records are generated by by using the Pairwise Item Similarity recommender system. Rnadomly choose 25 records out of the top 50 recommendations. 'stay_time' is randomly assigned value range from 120 to 180.
#
# - 25 property records are selected from the rest of the dataset randomly with a random number between 30 - 90 as the 'stay-time'.

# %%
row_id = 10
k = 50
top_50 = similarity(row_id, df_sample, k)  
# top_50

# %%
np.random.seed(0)
interst = top_50.sample(n = 25)
interst = (interst-df_sample.mean())/df_sample.std()
interst['stay_time'] = np.random.randint(120, 180, interst.shape[0])
# interst

# %%
np.random.seed(0)
uninterst = pd.concat([df_sample, top_50]).drop_duplicates(keep=False).sample(n = 25)
uninterst = (uninterst-df_sample.mean())/df_sample.std()
uninterst['stay_time'] = np.random.randint(30, 90, uninterst.shape[0])
# uninterst

# %%
history_realvalue = pd.concat([interst, uninterst])
# history_realvalue

# %% [markdown]
# ### Calculate the user rating based on the time user spend on each property page.

# %%
history_realvalue['rating'] = (history_realvalue['stay_time']-history_realvalue['stay_time'].mean())/history_realvalue['stay_time'].std()
# history_realvalue

# %% [markdown]
# ### Generate user profile based on the normalized rating

# %%
history_normalize = history_realvalue[["property_type", "tenure", "built_year", "num_beds", "num_baths", "size_sqft", "lat", "lng", "price"]].multiply(history["rating"], axis="index")
# history_normalize

# %%
user_profile = history_normalize.sum(axis=0)
user_profile = pd.DataFrame([user_profile])
user_profile
# Out:
#    property_type     tenure  built_year  num_beds  num_baths  size_sqft  \
# 0      16.726666  28.305198   19.708695 -17.81722  -23.01488  -1.348344
#
#         lat       lng     price
# 0 -0.556777 -0.164371 -0.106868

# %% [markdown]
# ### Get top k recommendations

# %%
k = 3
result_real_value = similarity(user_profile, df_sample, k)
result_real_value
# Out:
#        property_type  tenure  built_year  num_beds  num_baths  size_sqft  \
# 15681              2       2      2024.0       2.0        1.0        721
# 13626              2       2      2024.0       2.0        1.0        603
# 11481              2       2      2024.0       2.0        1.0        603
#
#             lat         lng      price
# 15681  1.339338  103.763893  1746200.0
# 13626  1.339338  103.763893  1702000.0
# 11481  1.339338  103.763893  1344000.0

# %% [markdown]
# ### Evaluate the performance by calculating intra-list similrity

# %%
result_real_value_intra = pairwise.pairwise_distances(result_real_value, metric='cosine')
result_real_value_intra.sum()/(k*k - k)
# Out:
# 3.92936321628549e-08
